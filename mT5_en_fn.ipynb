# %%
import pandas as pd

# %%
cd C:\Users\Mukaffi\Regional speech
# Out:
# C:\Users\Mukaffi\Regional speech

# %%
test_data = pd.read_csv("test.csv")

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")
validation_data = pd.read_csv("dev.csv")

# %%
train_data.head(5)
# Out:
#                                                   en  \
# 0  « Lucy va-t-elle toujours bien ? demanda-t-il,...
# 1  Whilst we were thus enjoying the sweets of rep...
# 2  "It was very essential for Stapleton to get so...
# 3  Provided that she was left alone to stroll in ...
# 4  "Yes," replied the gypsy; "it is to be brother...
#
#                                                   fr
# 0  "Does Lucy bear up well?" he asked, when he ha...
# 1  Pendant que chacun s'abandonnait ainsi à toute...
# 2  « L’essentiel était pour Stapleton de se procu...
# 3  Pourvu qu’on la laissât seule errer dans son b...
# 4  – Oui, répondit l’égyptienne. C’est être frère...

# %%
# Rename the columns to match the expected format
train_data.rename(columns={'en': 'input_text', 'fr': 'labels'}, inplace=True)
train_data.head()
# Out:
#                                           input_text  \
# 0  « Lucy va-t-elle toujours bien ? demanda-t-il,...
# 1  Whilst we were thus enjoying the sweets of rep...
# 2  "It was very essential for Stapleton to get so...
# 3  Provided that she was left alone to stroll in ...
# 4  "Yes," replied the gypsy; "it is to be brother...
#
#                                               labels
# 0  "Does Lucy bear up well?" he asked, when he ha...
# 1  Pendant que chacun s'abandonnait ainsi à toute...
# 2  « L’essentiel était pour Stapleton de se procu...
# 3  Pourvu qu’on la laissât seule errer dans son b...
# 4  – Oui, répondit l’égyptienne. C’est être frère...

# %%
test_data.head(5)
# Out:
#                                                   en  \
# 0  Altamira looked at her in astonishment; Julien...
# 1  "Already empty, ~cor−boeuf~! and I have no mor...
# 2  The deaf man had closed it behind him when he ...
# 3     So you'll do no more than say Farewell, Jane?"
# 4  You don't deceive a woman like me, my dear fri...
#
#                                                   fr
# 0  Altamira la regarda étonné, Julien ne daigna p...
# 1  « Déjà vide, corbœuf ! et je n’ai plus d’argent !
# 2  Le sourd en entrant dans la galerie l’avait fe...
# 3  Mais non, cela ne me suffirait pas; ainsi donc...
# 4  On ne trompe pas une femme comme moi, mon cher...

# %%
# Rename the columns to match the expected format
test_data.rename(columns={'en': 'input_text', 'fr': 'labels'}, inplace=True)
test_data.head()
# Out:
#                                           input_text  \
# 0  Altamira looked at her in astonishment; Julien...
# 1  "Already empty, ~cor−boeuf~! and I have no mor...
# 2  The deaf man had closed it behind him when he ...
# 3     So you'll do no more than say Farewell, Jane?"
# 4  You don't deceive a woman like me, my dear fri...
#
#                                               labels
# 0  Altamira la regarda étonné, Julien ne daigna p...
# 1  « Déjà vide, corbœuf ! et je n’ai plus d’argent !
# 2  Le sourd en entrant dans la galerie l’avait fe...
# 3  Mais non, cela ne me suffirait pas; ainsi donc...
# 4  On ne trompe pas une femme comme moi, mon cher...

# %%
validation_data.head(5)
# Out:
#                                                   en  \
# 0  After my mother's death, I wash my hands of yo...
# 1  We took him by a shoulder each and turned him ...
# 2           Now you talk, my dear." "You pardon me?"
# 3  He was meditating an enlarged programme; that ...
# 4  He asked him how many shirts he had ordered fr...
#
#                                                   fr
# 0  après la mort de ma mère, je ne m'inquiète plu...
# 1  Nous le prîmes chacun par une épaule et léten...
# 2     -- Nous verrons», dit majestueusement Porthos.
# 3  Il méditait d'élargir son programme, l'affinem...
# 4  Il lui demanda combien il avait pris de chemis...

# %%
# Rename the columns to match the expected format
validation_data.rename(columns={'en': 'input_text', 'fr': 'labels'}, inplace=True)
validation_data.head()
# Out:
#                                           input_text  \
# 0  After my mother's death, I wash my hands of yo...
# 1  We took him by a shoulder each and turned him ...
# 2           Now you talk, my dear." "You pardon me?"
# 3  He was meditating an enlarged programme; that ...
# 4  He asked him how many shirts he had ordered fr...
#
#                                               labels
# 0  après la mort de ma mère, je ne m'inquiète plu...
# 1  Nous le prîmes chacun par une épaule et léten...
# 2     -- Nous verrons», dit majestueusement Porthos.
# 3  Il méditait d'élargir son programme, l'affinem...
# 4  Il lui demanda combien il avait pris de chemis...

# %%
# !pip install transformers torch pandas
# Out:
# Requirement already satisfied: transformers in c:\users\mukaffi\anaconda3\lib\site-packages (4.35.2)
# Requirement already satisfied: torch in c:\users\mukaffi\anaconda3\lib\site-packages (2.1.1+cu118)
# Requirement already satisfied: pandas in c:\users\mukaffi\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (2.29.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mukaffi\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)

# %%
import transformers
import torch

print("transformers version:", transformers.__version__)
print("torch version:", torch.__version__)
# Out:
# transformers version: 4.35.2
# torch version: 2.1.1+cu118

# %%
#pip install transformers==4.35.2

# %%
#pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
import torch

# Check if GPU (CUDA) is available
if torch.cuda.is_available():
    # Get the number of available GPUs
    num_gpus = torch.cuda.device_count()
    
    # Display GPU information
    for i in range(num_gpus):
        gpu_name = torch.cuda.get_device_name(i)
        print(f"GPU {i}: {gpu_name}")
else:
    print("No GPU (CUDA) devices available.")
# Out:
# GPU 0: NVIDIA GeForce RTX 3050

# %%
# !pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in c:\users\mukaffi\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: portalocker in c:\users\mukaffi\anaconda3\lib\site-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in c:\users\mukaffi\anaconda3\lib\site-packages (from sacrebleu) (2022.7.9)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\mukaffi\anaconda3\lib\site-packages (from sacrebleu) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from sacrebleu) (1.24.3)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\mukaffi\anaconda3\lib\site-packages (from sacrebleu) (4.9.2)
# Requirement already satisfied: pywin32>=226 in c:\users\mukaffi\anaconda3\lib\site-packages (from portalocker->sacrebleu) (305.1)

# %%
# !pip install rouge_score
# Out:
# Requirement already satisfied: rouge_score in c:\users\mukaffi\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: absl-py in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge_score) (2.0.0)
# Requirement already satisfied: nltk in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge_score) (3.7)
# Requirement already satisfied: numpy in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge_score) (1.24.3)
# Requirement already satisfied: six>=1.14.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge_score) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge_score) (4.65.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from click->nltk->rouge_score) (0.4.6)

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in c:\users\mukaffi\anaconda3\lib\site-packages (0.1.99)

# %%
# !pip install transformers[sentencepiece]
# Out:
# Requirement already satisfied: transformers[sentencepiece] in c:\users\mukaffi\anaconda3\lib\site-packages (4.35.2)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (2.29.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (4.65.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[sentencepiece]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers[sentencepiece]) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers[sentencepiece]) (4.5.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers[sentencepiece]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (2023.7.22)

# %%
# !transformers-cli cache clear
# Out:
# usage: transformers-cli <command> [<args>]
# Transformers CLI tool: error: argument {convert,download,env,run,serve,login,whoami,logout,repo,add-new-model,add-new-model-like,lfs-enable-largefiles,lfs-multipart-upload,pt-to-tf}: invalid choice: 'cache' (choose from 'convert', 'download', 'env', 'run', 'serve', 'login', 'whoami', 'logout', 'repo', 'add-new-model', 'add-new-model-like', 'lfs-enable-largefiles', 'lfs-multipart-upload', 'pt-to-tf')

# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in c:\users\mukaffi\anaconda3\lib\site-packages (4.35.2)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (2.29.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (4.65.0)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (2.1.1+cu118)
# Requirement already satisfied: accelerate>=0.20.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: psutil in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in c:\users\mukaffi\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.11.1)
# Requirement already satisfied: networkx in c:\users\mukaffi\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\mukaffi\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[torch]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[torch]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers[torch]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mukaffi\anaconda3\lib\site-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.2.1)

# %%
# !pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in c:\users\mukaffi\anaconda3\lib\site-packages (0.24.1)
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (23.0)
# Requirement already satisfied: psutil in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (2.1.1+cu118)
# Requirement already satisfied: huggingface-hub in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from accelerate) (0.4.0)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\mukaffi\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in c:\users\mukaffi\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in c:\users\mukaffi\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\mukaffi\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mukaffi\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: requests in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2.29.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (4.65.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mukaffi\anaconda3\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.2.1)
# Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#    ---------------------------------------- 0.0/265.7 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/265.7 kB 1.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 30.7/265.7 kB 1.4 MB/s eta 0:00:01
#    --------- ----------------------------- 61.4/265.7 kB 544.7 kB/s eta 0:00:01
#    ---------------- --------------------- 112.6/265.7 kB 731.4 kB/s eta 0:00:01
#    -------------------- ----------------- 143.4/265.7 kB 711.9 kB/s eta 0:00:01
#    --------------------------------- ---- 235.5/265.7 kB 962.7 kB/s eta 0:00:01
#    ------------------------------------ - 256.0/265.7 kB 874.6 kB/s eta 0:00:01
#    -------------------------------------- 265.7/265.7 kB 860.1 kB/s eta 0:00:00
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.24.1
#     Uninstalling accelerate-0.24.1:
#       Successfully uninstalled accelerate-0.24.1
# Successfully installed accelerate-0.25.0

# %%
# !pip install git+https://github.com/csebuetnlp/normalizer
# Out:
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to c:\users\mukaffi\appdata\local\temp\pip-req-build-0ezx7zty
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: regex in c:\users\mukaffi\anaconda3\lib\site-packages (from normalizer==0.0.1) (2022.7.9)
# Requirement already satisfied: emoji==1.4.2 in c:\users\mukaffi\anaconda3\lib\site-packages (from normalizer==0.0.1) (1.4.2)
# Requirement already satisfied: ftfy==6.0.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from normalizer==0.0.1) (6.0.3)
# Requirement already satisfied: wcwidth in c:\users\mukaffi\anaconda3\lib\site-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.5)
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer 'C:\Users\Mukaffi\AppData\Local\Temp\pip-req-build-0ezx7zty'

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\mukaffi\anaconda3\lib\site-packages (23.3.1)

# %%
# !pip install transformers==4.10.3
# Out:
# Collecting transformers==4.10.3
#   Using cached transformers-4.10.3-py3-none-any.whl (2.8 MB)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (3.9.0)
# Requirement already satisfied: huggingface-hub>=0.0.12 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (1.24.3)
# Requirement already satisfied: packaging in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (2.29.0)
# Requirement already satisfied: sacremoses in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (0.0.43)
# Collecting tokenizers<0.11,>=0.10.1 (from transformers==4.10.3)
#   Downloading tokenizers-0.10.3.tar.gz (212 kB)
#      ---------------------------------------- 0.0/212.7 kB ? eta -:--:--
#      ----- ------------------------------- 30.7/212.7 kB 660.6 kB/s eta 0:00:01
#      ----- ------------------------------- 30.7/212.7 kB 660.6 kB/s eta 0:00:01
#      ------------ ------------------------ 71.7/212.7 kB 435.7 kB/s eta 0:00:01
#      ------------------- ---------------- 112.6/212.7 kB 656.4 kB/s eta 0:00:01
#      ------------------------- ---------- 153.6/212.7 kB 610.0 kB/s eta 0:00:01
#      ------------------------------------ 212.7/212.7 kB 761.2 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.27 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers==4.10.3) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub>=0.0.12->transformers==4.10.3) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub>=0.0.12->transformers==4.10.3) (4.5.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.10.3) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers==4.10.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers==4.10.3) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers==4.10.3) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers==4.10.3) (2023.7.22)
# Requirement already satisfied: six in c:\users\mukaffi\anaconda3\lib\site-packages (from sacremoses->transformers==4.10.3) (1.16.0)
# Requirement already satisfied: click in c:\users\mukaffi\anaconda3\lib\site-packages (from sacremoses->transformers==4.10.3) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mukaffi\anaconda3\lib\site-packages (from sacremoses->transformers==4.10.3) (1.2.0)
# Building wheels for collected packages: tokenizers
#   Building wheel for tokenizers (pyproject.toml): started
#   Building wheel for tokenizers (pyproject.toml): finished with status 'error'
# Failed to build tokenizers
#   error: subprocess-exited-with-error
#
#   Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [51 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\tokenizers
#   copying py_src\tokenizers\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers
#   creating build\lib.win-amd64-cpython-311\tokenizers\models
#   copying py_src\tokenizers\models\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\models
#   creating build\lib.win-amd64-cpython-311\tokenizers\decoders
#   copying py_src\tokenizers\decoders\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\decoders
#   creating build\lib.win-amd64-cpython-311\tokenizers\normalizers
#   copying py_src\tokenizers\normalizers\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\normalizers
#   creating build\lib.win-amd64-cpython-311\tokenizers\pre_tokenizers
#   copying py_src\tokenizers\pre_tokenizers\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\pre_tokenizers
#   creating build\lib.win-amd64-cpython-311\tokenizers\processors
#   copying py_src\tokenizers\processors\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\processors
#   creating build\lib.win-amd64-cpython-311\tokenizers\trainers
#   copying py_src\tokenizers\trainers\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\trainers
#   creating build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\base_tokenizer.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\bert_wordpiece.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\byte_level_bpe.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\char_level_bpe.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\sentencepiece_bpe.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\sentencepiece_unigram.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   copying py_src\tokenizers\implementations\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\implementations
#   creating build\lib.win-amd64-cpython-311\tokenizers\tools
#   copying py_src\tokenizers\tools\visualizer.py -> build\lib.win-amd64-cpython-311\tokenizers\tools
#   copying py_src\tokenizers\tools\__init__.py -> build\lib.win-amd64-cpython-311\tokenizers\tools
#   copying py_src\tokenizers\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers
#   copying py_src\tokenizers\models\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers\models
#   copying py_src\tokenizers\decoders\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers\decoders
#   copying py_src\tokenizers\normalizers\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers\normalizers
#   copying py_src\tokenizers\pre_tokenizers\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers\pre_tokenizers
#   copying py_src\tokenizers\processors\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers\processors
#   copying py_src\tokenizers\trainers\__init__.pyi -> build\lib.win-amd64-cpython-311\tokenizers\trainers
#   copying py_src\tokenizers\tools\visualizer-styles.css -> build\lib.win-amd64-cpython-311\tokenizers\tools
#   running build_ext
#   running build_rust
#   error: can't find Rust compiler
#
#   If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#   To update pip, run:
#
#       pip install --upgrade pip
#
#   and then retry package installation.
#
#   If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects

# %%
# !pip install torch transformers
# Out:
# Requirement already satisfied: torch in c:\users\mukaffi\anaconda3\lib\site-packages (2.1.1+cu118)
# Requirement already satisfied: transformers in c:\users\mukaffi\anaconda3\lib\site-packages (4.35.2)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mukaffi\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (2.29.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mukaffi\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mukaffi\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)

# %%
#!pip install accelerate==0.20.3

# %%
# !pip install git+https://github.com/csebuetnlp/normalizer
# Out:
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to c:\users\mukaffi\appdata\local\temp\pip-req-build-fakv8ob_
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: regex in c:\users\mukaffi\anaconda3\lib\site-packages (from normalizer==0.0.1) (2022.7.9)
# Requirement already satisfied: emoji==1.4.2 in c:\users\mukaffi\anaconda3\lib\site-packages (from normalizer==0.0.1) (1.4.2)
# Requirement already satisfied: ftfy==6.0.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from normalizer==0.0.1) (6.0.3)
# Requirement already satisfied: wcwidth in c:\users\mukaffi\anaconda3\lib\site-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.5)
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer 'C:\Users\Mukaffi\AppData\Local\Temp\pip-req-build-fakv8ob_'

# %%
pip install protobuf==3.20
# Out:
# Requirement already satisfied: protobuf==3.20 in c:\users\mukaffi\anaconda3\lib\site-packages (3.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Load the model and tokenizer**

# %%
'''import torch
from transformers import MT5ForConditionalGeneration, AutoTokenizer
#https://huggingface.co/docs/transformers/model_doc/mt5
model_name = "google/mt5-small" # The variations it has -> mt5-small: 6, mt5-base: 12,mt5-large: 24, mt5-xl: 24, mt5-xxl: 24
model = MT5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")'''
# Out:
# 'import torch\nfrom transformers import MT5ForConditionalGeneration, AutoTokenizer\n#https://huggingface.co/docs/transformers/model_doc/mt5\nmodel_name = "google/mt5-small" # The variations it has -> mt5-small: 6, mt5-base: 12,mt5-large: 24, mt5-xl: 24, mt5-xxl: 24\nmodel = MT5ForConditionalGeneration.from_pretrained(model_name)\ntokenizer = AutoTokenizer.from_pretrained(model_name)\ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")'

# %%
import torch
from normalizer import normalize
from transformers import MT5ForConditionalGeneration, AutoTokenizer ,DataCollatorForSeq2Seq, Trainer, TrainingArguments
import os


model_name = "google/mt5-small" 
model = MT5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
from torch.utils.data import Dataset, DataLoader
class Seq2SeqDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.input_text = data['input_text'].apply(normalize).tolist()
        self.labels = data['labels'].apply(normalize).tolist()
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.input_text)

    def __getitem__(self, idx):
        input_text = self.input_text[idx]
        label_text = self.labels[idx]

        # Tokenize the input text
        input_encodings = self.tokenizer(
            input_text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        # Tokenize the label text to get its 'input_ids' and 'attention_mask'
        label_encodings = self.tokenizer(
            label_text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        return {
            'input_ids': input_encodings['input_ids'].squeeze(),
            'attention_mask': input_encodings['attention_mask'].squeeze(),
            'labels': label_encodings['input_ids'].squeeze(),
        }

# %%
# Modify the data collation process to handle PyTorch tensors correctly
class MyDataCollatorForSeq2Seq(DataCollatorForSeq2Seq):
    def __call__(self, features):
        batch = {}
        batch["input_ids"] = torch.stack([feature["input_ids"] for feature in features])
        batch["attention_mask"] = torch.stack([feature["attention_mask"] for feature in features])

        # Labels should be processed differently for PyTorch tensors
        if isinstance(features[0]["labels"], torch.Tensor):
            batch["labels"] = torch.stack([feature["labels"] for feature in features])
        else:
            # Convert the list of lists to a PyTorch tensor
            batch["labels"] = torch.tensor([feature["labels"] for feature in features])

        return batch

# %%
# Create train , test and validation datasets
train_dataset = Seq2SeqDataset(train_data, tokenizer)
test_dataset = Seq2SeqDataset(test_data, tokenizer)
validation_dataset = Seq2SeqDataset(validation_data, tokenizer)

# Create train , test and validation dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)  #batch_size=32
test_dataloader = DataLoader(test_dataset, batch_size=32) #batch_size=32
validation_dataloader = DataLoader(validation_dataset, batch_size=32) #batch_size=32

# %%
# Move the model to the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Move the model to the device (CPU or GPU)
model.to(device)
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 512)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=250112, bias=False)
# )

# %%
# Create a custom optimizer using torch.optim.AdamW
custom_optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    eps=1e-8,
    weight_decay=0.01,
)

# %%
#pip install accelerate -U

# %%
# Define the TrainingArguments for fine-tuning
training_args = TrainingArguments(
    output_dir='D:\\Datasets\\Thesis Data Test',
    num_train_epochs=1,
    per_device_train_batch_size=5,
    gradient_accumulation_steps=8,
    evaluation_strategy="epoch",
    save_total_limit=0,
    save_steps=15000,
    learning_rate=1e-3,
    do_train=True,
    do_eval=True,
    remove_unused_columns=False,
    push_to_hub=False,
    report_to="none",
    load_best_model_at_end=False,
    lr_scheduler_type="cosine_with_restarts",
    warmup_steps=100,
    weight_decay=0.01,
    logging_dir='D:\\Datasets\\Thesis Data Test',
    logging_steps=200,
    
)

# %%
# Create a data collator for sequence-to-sequence tasks
data_collator = MyDataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding=False,
    max_length=80,
    label_pad_token_id=tokenizer.pad_token_id,
)

# %%
# Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    optimizers=(custom_optimizer, None),
)

# %%
# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='1540' max='1906' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1540/1906 4:13:20 < 1:00:17, 0.10 it/s, Epoch 0.81/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
'''import pandas as pd
import torch
from normalizer import normalize
from transformers import MT5ForConditionalGeneration, AutoTokenizer, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader

# Assuming you have the necessary imports and data loading steps

class Seq2SeqDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.input_text = data['input_text'].apply(normalize).tolist()
        self.labels = data['labels'].apply(normalize).tolist()
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.input_text)

    def __getitem__(self, idx):
        input_text = self.input_text[idx]
        label_text = self.labels[idx]

        # Tokenize the input text
        input_encodings = self.tokenizer(
            input_text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        # Tokenize the label text to get its 'input_ids' and 'attention_mask'
        label_encodings = self.tokenizer(
            label_text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        return {
            'input_ids': input_encodings['input_ids'].squeeze(),
            'attention_mask': input_encodings['attention_mask'].squeeze(),
            'labels': label_encodings['input_ids'].squeeze(),
        }

# Modify the data collation process to handle PyTorch tensors correctly
class MyDataCollatorForSeq2Seq(DataCollatorForSeq2Seq):
    def __call__(self, features):
        batch = {}
        batch["input_ids"] = torch.stack([feature["input_ids"] for feature in features])
        batch["attention_mask"] = torch.stack([feature["attention_mask"] for feature in features])

        # Labels should be processed differently for PyTorch tensors
        if isinstance(features[0]["labels"], torch.Tensor):
            batch["labels"] = torch.stack([feature["labels"] for feature in features])
        else:
            # Convert the list of lists to a PyTorch tensor
            batch["labels"] = torch.tensor([feature["labels"] for feature in features])

        return batch

# Load the saved model
model = MT5ForConditionalGeneration.from_pretrained("C:\\Users\\Mukaffi\\Desktop\\fariya\\sylhet_translation_mT5.pt\\sylhet_translation_mT5.pt")

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("C:\\Users\Mukaffi\\Desktop\\fariya\\sylhet_tokenizer_mT5.json\\sylhet_tokenizer_mT5.json")

# Create train dataset
train_dataset = Seq2SeqDataset(train_data, tokenizer)

# Create train dataloader
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# Move the model to the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Create a custom optimizer using torch.optim.AdamW
custom_optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    eps=1e-8,
    weight_decay=0.01,
)

# Define the TrainingArguments for fine-tuning
training_args = TrainingArguments(
    output_dir='D:\\Datasets\\Thesis Data Test',
    num_train_epochs=1,
    per_device_train_batch_size=6,
    gradient_accumulation_steps=8,
    evaluation_strategy="steps",
    eval_steps=10,
    save_total_limit=2,
    save_steps=15000,
    learning_rate=1e-3,
    do_train=True,
    do_eval=True,
    remove_unused_columns=False,
    push_to_hub=False,
    report_to="none",
    load_best_model_at_end=True,
    lr_scheduler_type="cosine_with_restarts",
    warmup_steps=100,
    weight_decay=0.01,
    logging_dir='D:\\Datasets\\Thesis Data Test',
    logging_steps=100,
)

# Create a data collator for sequence-to-sequence tasks
data_collator = MyDataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding=False,
    max_length=128,
    label_pad_token_id=tokenizer.pad_token_id,
)

# Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    optimizers=(custom_optimizer, None),
)

# Fine-tune the model
trainer.train()
'''
# Out:
# 'import pandas as pd\nimport torch\nfrom normalizer import normalize\nfrom transformers import MT5ForConditionalGeneration, AutoTokenizer, DataCollatorForSeq2Seq, Trainer, TrainingArguments\nfrom torch.utils.data import Dataset, DataLoader\n\n# Assuming you have the necessary imports and data loading steps\n\nclass Seq2SeqDataset(Dataset):\n    def __init__(self, data, tokenizer, max_length=128):\n        self.input_text = data[\'input_text\'].apply(normalize).tolist()\n        self.labels = data[\'labels\'].apply(normalize).tolist()\n        self.tokenizer = tokenizer\n        self.max_length = max_length\n\n    def __len__(self):\n        return len(self.input_text)\n\n    def __getitem__(self, idx):\n        input_text = self.input_text[idx]\n        label_text = self.labels[idx]\n\n        # Tokenize the input text\n        input_encodings = self.tokenizer(\n            input_text,\n            truncation=True,\n            padding=\'max_length\',\n            max_length=self.max_length,\n            return_tensors=\'pt\'\n        )\n\n        # Tokenize the label text to get its \'input_ids\' and \'attention_mask\'\n        label_encodings = self.tokenizer(\n            label_text,\n            truncation=True,\n            padding=\'max_length\',\n            max_length=self.max_length,\n            return_tensors=\'pt\'\n        )\n\n        return {\n            \'input_ids\': input_encodings[\'input_ids\'].squeeze(),\n            \'attention_mask\': input_encodings[\'attention_mask\'].squeeze(),\n            \'labels\': label_encodings[\'input_ids\'].squeeze(),\n        }\n\n# Modify the data collation process to handle PyTorch tensors correctly\nclass MyDataCollatorForSeq2Seq(DataCollatorForSeq2Seq):\n    def __call__(self, features):\n        batch = {}\n        batch["input_ids"] = torch.stack([feature["input_ids"] for feature in features])\n        batch["attention_mask"] = torch.stack([feature["attention_mask"] for feature in features])\n\n        # Labels should be processed differently for PyTorch tensors\n        if isinstance(features[0]["labels"], torch.Tensor):\n            batch["labels"] = torch.stack([feature["labels"] for feature in features])\n        else:\n            # Convert the list of lists to a PyTorch tensor\n            batch["labels"] = torch.tensor([feature["labels"] for feature in features])\n\n        return batch\n\n# Load the saved model\nmodel = MT5ForConditionalGeneration.from_pretrained("C:\\Users\\Mukaffi\\Desktop\\fariya\\sylhet_translation_mT5.pt\\sylhet_translation_mT5.pt")\n\n# Load the tokenizer\ntokenizer = AutoTokenizer.from_pretrained("C:\\Users\\Mukaffi\\Desktop\\fariya\\sylhet_tokenizer_mT5.json\\sylhet_tokenizer_mT5.json")\n\n# Create train dataset\ntrain_dataset = Seq2SeqDataset(train_data, tokenizer)\n\n# Create train dataloader\ntrain_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)\n\n# Move the model to the device\ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")\nmodel.to(device)\n\n# Create a custom optimizer using torch.optim.AdamW\ncustom_optimizer = torch.optim.AdamW(\n    model.parameters(),\n    lr=1e-3,\n    eps=1e-8,\n    weight_decay=0.01,\n)\n\n# Define the TrainingArguments for fine-tuning\ntraining_args = TrainingArguments(\n    output_dir=\'D:\\Datasets\\Thesis Data Test\',\n    num_train_epochs=1,\n    per_device_train_batch_size=6,\n    gradient_accumulation_steps=8,\n    evaluation_strategy="steps",\n    eval_steps=10,\n    save_total_limit=2,\n    save_steps=15000,\n    learning_rate=1e-3,\n    do_train=True,\n    do_eval=True,\n    remove_unused_columns=False,\n    push_to_hub=False,\n    report_to="none",\n    load_best_model_at_end=True,\n    lr_scheduler_type="cosine_with_restarts",\n    warmup_steps=100,\n    weight_decay=0.01,\n    logging_dir=\'D:\\Datasets\\Thesis Data Test\',\n    logging_steps=100,\n)\n\n# Create a data collator for sequence-to-sequence tasks\ndata_collator = MyDataCollatorForSeq2Seq ...

# %% [markdown]
# # **Save the model**

# %%
from transformers import AutoModelForSeq2SeqLM

# Save the model
model.save_pretrained("E:\\Fariya\\translation_mT5.pt")

# Save the tokenizer
tokenizer.save_pretrained("E:\\Fariya\\tokenizer_mT5.json")
# Out:
# ('E:\\Fariya\\tokenizer_mT5.json\\tokenizer_config.json',
#  'E:\\Fariya\\tokenizer_mT5.json\\special_tokens_map.json',
#  'E:\\Fariya\\tokenizer_mT5.json\\spiece.model',
#  'E:\\Fariya\\tokenizer_mT5.json\\added_tokens.json',
#  'E:\\Fariya\\tokenizer_mT5.json\\tokenizer.json')

# %% [markdown]
# # **Load the model again**

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Load the saved model
model = AutoModelForSeq2SeqLM.from_pretrained("E:\\Fariya\\translation_mT5.pt")

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("E:\\Fariya\\tokenizer_mT5.json")

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\mukaffi\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (2.29.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub>=0.18.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub>=0.18.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: python-Levenshtein in c:\users\mukaffi\anaconda3\lib\site-packages (0.23.0)
# Requirement already satisfied: Levenshtein==0.23.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from python-Levenshtein) (0.23.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from Levenshtein==0.23.0->python-Levenshtein) (3.5.2)

# %%
# !pip install jiwer
# Out:
# Requirement already satisfied: jiwer in c:\users\mukaffi\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in c:\users\mukaffi\anaconda3\lib\site-packages (from jiwer) (3.5.2)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->jiwer) (0.4.6)

# %%
# Move the model to the device (CPU or GPU)
model.to(device)
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 512)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=250112, bias=False)
# )

# %%
# !pip install rouge-score
#https://github.com/google-research/google-research/tree/master/rouge
#https://huggingface.co/spaces/evaluate-metric/rouge [Different types of ROUGE scores]
# Out:
# Requirement already satisfied: rouge-score in c:\users\mukaffi\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: absl-py in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge-score) (2.0.0)
# Requirement already satisfied: nltk in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge-score) (3.7)
# Requirement already satisfied: numpy in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge-score) (1.24.3)
# Requirement already satisfied: six>=1.14.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge-score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge-score) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\mukaffi\anaconda3\lib\site-packages (from nltk->rouge-score) (4.65.0)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from click->nltk->rouge-score) (0.4.6)

# %%
# !pip install evaluate
# Out:
# Requirement already satisfied: evaluate in c:\users\mukaffi\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (2.15.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (1.24.3)
# Requirement already satisfied: dill in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (2.29.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2023.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (0.19.4)
# Requirement already satisfied: packaging in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (23.0)
# Requirement already satisfied: responses<0.19 in c:\users\mukaffi\anaconda3\lib\site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukaffi\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukaffi\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\mukaffi\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from pandas->evaluate) (2022.7)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mukaffi\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\mukaffi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)

# %%
import torch
import Levenshtein
from evaluate import load
# Define the move_to_device function
def move_to_device(batch, device):
    if isinstance(batch, torch.Tensor):
        return batch.to(device)
    elif isinstance(batch, list):
        return [move_to_device(item, device) for item in batch]
    elif isinstance(batch, dict):
        return {key: move_to_device(value, device) for key, value in batch.items()}
    else:
        return batch  # If it's not a tensor, list, or dict, leave it as is

# Load the evaluation metric for Character Error Rate (CER) and Word Error Rate (WER) and Exact Match(em)
cer_metric = load("cer")
wer_metric = load("wer")
meteor = load('meteor')
exact_match_metric = load("exact_match")

# Load BLEU and ROUGE metrics
bleu_metric = load("bleu")
rouge_metric = load('rouge')

# Initialize lists to store generated translations and references
generated_translations = []
references = []

# Generate translations for the test dataset
for batch in test_dataloader:
    # Move the batch to CUDA
    batch = move_to_device(batch, 'cuda')

    input_text = batch['input_ids']  # Access the input_text using the correct key
    labels = batch['labels']  # Access the labels using the correct key
    print(input_text)
    # Generate translations
    translation_ids = model.generate(input_text, max_length=50, num_beams=4, length_penalty=2.0, early_stopping=True)

    # Move the translation_ids to CPU to decode
    translation_ids = translation_ids.to('cpu')

    generated_translation = tokenizer.batch_decode(translation_ids, skip_special_tokens=True)

    generated_translations.extend(generated_translation)
    references.extend(tokenizer.batch_decode(labels, skip_special_tokens=True))  # Decoding the label IDs

# Make sure to move generated_translations back to CPU for evaluation if necessary
generated_translations = [translation if not isinstance(translation, str) else translation for translation in generated_translations]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mukaffi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mukaffi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Mukaffi\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# tensor([[26130, 40256,  4089,  ...,     0,     0,     0],
#         [  313,  7759, 12636,  ...,     0,     0,     0],
#         [  486,   269,  2066,  ...,     0,     0,     0],
#         ...,
#         [  486,   272,   790,  ...,     0,     0,     0],
#         [ 1494, 20815, 13636,  ...,     0,     0,     0],
#         [ 4837,  3256,   416,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   501,  59954,  15233,  ...,      0,      0,      0],
#         [   313,  41758,   3551,  ...,      0,      0,      0],
#         [   259,    277,  13344,  ...,      0,      0,      0],
#         ...,
#         [  1829,    287,    259,  ...,      0,      0,      0],
#         [   313, 161083,   9496,  ...,      0,      0,      0],
#         [  5258,    569,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  4879,    265,    304,  ...,      0,      0,      0],
#         [   259,    264,    371,  ...,      0,      0,      0],
#         [ 23419,    282, 218156,  ...,      0,      0,      0],
#         ...,
#         [   653,   4976,    455,  ...,      0,      0,      0],
#         [   336,   3609,   8103,  ...,      0,      0,      0],
#         [   313,  95841,    339,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 21490,  7599,  ...,     0,     0,     0],
#         [  313, 13673,   339,  ...,     0,     0,     0],
#         [ 1829,  1469,   259,  ...,     0,     0,     0],
#         ...,
#         [  486,   272,   702,  ...,     0,     0,     0],
#         [  486,   259, 61840,  ...,     0,     0,     0],
#         [  313, 11780,   639,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  5258,    418,   2956,  ...,      0,      0,      0],
#         [   486,    272,    790,  ...,      0,      0,      0],
#         [   298,    259, 143210,  ...,      0,      0,      0],
#         ...,
#         [   336,    259, 106032,  ...,      0,      0,      0],
#         [   313,  57042,  48603,  ...,      0,      0,      0],
#         [ 45864, 183181,    345,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 1494,   259, 73912,  ...,     0,     0,     0],
#         [ 1669,   639,   390,  ...,     0,     0,     0],
#         [ 1385,   639,   259,  ...,     0,     0,     0],
#         ...,
#         [ 3126,   259,   262,  ...,     0,     0,     0],
#         [24830, 31533,  5123,  ...,     0,     0,     0],
#         [ 6928,   631,  8103,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 14197,    309,    259,  ...,      0,      0,      0],
#         [  4837,    521,   3659,  ...,      0,      0,      0],
#         [   371, 177792,    484,  ...,      0,      0,      0],
#         ...,
#         [   336,    259,  51884,  ...,      0,      0,      0],
#         [   363,  42888,  49332,  ...,      0,      0,      0],
#         [   486,   9137,    861,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  486, 14802, 16603,  ...,     0,     0,     0],
#         [ 7898,   263,  2451,  ...,     0,     0,     0],
#         [ 4837,   527,   287,  ...,     0,     0,     0],
#         ...,
#         [  336,   277,   857,  ...,     0,     0,     0],
#         [  313, 18402,  4403,  ...,     0,     0,     0],
#         [ 1477,   287, 40864,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   336,   5897,    336,  ...,      0,      0,      0],
#         [   313, 126629,    631,  ...,      0,      0,      0],
#         [   764,  27478,  64256,  ...,    259,    276,      1],
#         ...,
#         [  2585,  51816,    340,  ...,      0,      0,      0],
#         [   259, 105907,    639,  ...,      0,      0,      0],
#         [ 96484,    259,    290,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313, 203894,   5038,  ...,      0,      0,      0],
#         [  5987, 196368,    305,  ...,      0,      0,      0],
#         [  2584,    287,  41094,  ...,      0,      0,      0],
#         ...,
#         [   298,    268,   6960,  ...,      0,      0,      0],
#         [   259, 101388,    265,  ...,      0,      0,      0],
#         [  1272,    521,   4875,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313, 116048,    261,  ...,      0,      0,      0],
#         [   486,  18860, 177979,  ...,      0,      0,      0],
#         [   926,    390,  47682,  ...,      0,      0,      0],
#         ...,
#         [ 18241,    347,   2130,  ...,      0,      0,      0],
#         [  5258,    418,    259,  ...,      0,      0,      0],
#         [  3126,  10891,    288,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  1306,    783,   1627,  ...,      0,      0,      0],
#         [   313,  35286,  14047,  ...,      0,      0,      0],
#         [   336,   1425,    289,  ...,      0,      0,      0],
#         ...,
#         [   313,  38054,    261,  ...,      0,      0,      0],
#         [   313,  64210,    787,  ...,      0,      0,      0],
#         [106210,    285,    287,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 18948,  6225,  ...,     0,     0,     0],
#         [  486,   272,   609,  ...,     0,     0,     0],
#         [ 1102,  2956,  5382,  ...,     0,     0,     0],
#         ...,
#         [  336,   728,  7779,  ...,     0,     0,     0],
#         [ 4837,  2119,   738,  ...,     0,     0,     0],
#         [ 2694,  1425,   776,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  259,   264, 22407,  ...,     0,     0,     0],
#         [  313,   566,   259,  ...,     0,     0,     0],
#         [  313, 90492,   914,  ...,     0,     0,     0],
#         ...,
#         [ 4630,  2426,   609,  ...,     0,     0,     0],
#         [ 1669,   339,   287,  ...,     0,     0,     0],
#         [ 1641,   520,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  313,   566,  3007,  ...,     0,     0,     0],
#         [  313,   566,   259,  ...,     0,     0,     0],
#         [  336,   259,  3659,  ...,     0,     0,     0],
#         ...,
#         [ 2953,   304,  1406,  ...,     0,     0,     0],
#         [30695,   914,  9489,  ...,     0,     0,     0],
#         [  259, 14833, 36100,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   336,    639,    259,  ...,      0,      0,      0],
#         [ 13889,    259, 209747,  ...,      0,      0,      0],
#         [   313, 102155,    339,  ...,      0,      0,      0],
#         ...,
#         [   259,    264,   2845,  ...,      0,      0,      0],
#         [  4837,    332,    751,  ...,      0,      0,      0],
#         [  4837,    790,   1607,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 10525,   316,  ...,     0,     0,     0],
#         [ 5483,   347,   287,  ...,     0,     0,     0],
#         [  313, 11544, 34606,  ...,     0,     0,     0],
#         ...,
#         [ 4837,   287,  1711,  ...,     0,     0,     0],
#         [  313, 11780,   277,  ...,     0,     0,     0],
#         [  259, 79411,   520,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,  35619,    309,  ...,      0,      0,      0],
#         [   486,    272,    287,  ...,      0,      0,      0],
#         [   486,    259, 195995,  ...,      0,      0,      0],
#         ...,
#         [  7119,   1638,  19298,  ...,      0,      0,      0],
#         [   313,  18402,    259,  ...,      0,      0,      0],
#         [   313,  11544,  34606,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 1829,   510,   609,  ...,     0,     0,     0],
#         [  298, 17364, 24657,  ...,     0,     0,     0],
#         [ 1669,   259, 26702,  ...,     0,     0,     0],
#         ...,
#         [ 2584,  2262,   336,  ...,     0,     0,     0],
#         [11651,   259,  9390,  ...,     0,     0,     0],
#         [  313, 19374,   287,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 4630,  9489,   345,  ...,     0,     0,     0],
#         [  298,   712,  7285,  ...,     0,     0,     0],
#         [ 5100,  2857,   287,  ...,     0,     0,     0],
#         ...,
#         [ 2584,   259, 55236,  ...,     0,     0,     0],
#         [  259,   277, 13344,  ...,     0,     0,     0],
#         [ 4837,   955,  1037,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,  38054,    309,  ...,      0,      0,      0],
#         [  2368,  19341, 102488,  ...,      0,      0,      0],
#         [ 49234,    337,    259,  ...,      0,      0,      0],
#         ...,
#         [   486,   3230,    281,  ...,      0,      0,      0],
#         [ 21938,    281,    259,  ...,      0,      0,      0],
#         [   259,  35129,  21826,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,    545, 157914,  ...,      0,      0,      0],
#         [   563,    287,  15388,  ...,      0,      0,      0],
#         [   788, 111323,    287,  ...,      0,      0,      0],
#         ...,
#         [   313,  90492,    267,  ...,      0,      0,      0],
#         [   313,  47757,    309,  ...,      0,      0,      0],
#         [ 15737,   2108,   2109,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 2953,   304,   259,  ...,     0,     0,     0],
#         [33494,   265,   358,  ...,     0,     0,     0],
#         [  259,   277,  2009,  ...,     0,     0,     0],
#         ...,
#         [  313, 11750, 58503,  ...,     0,     0,     0],
#         [  259,  6397,   790,  ..., 24257,   260,     1],
#         [  259,   277, 88882,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   336,  19820,    287,  ...,      0,      0,      0],
#         [  5594,   1503,    270,  ...,      0,      0,      0],
#         [   313,  14721,    914,  ...,      0,      0,      0],
#         ...,
#         [   486,    259, 152982,  ...,      0,      0,      0],
#         [   443,    728,    299,  ...,      0,      0,      0],
#         [   313,  39715,  27089,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  336,  6744,   345,  ...,     0,     0,     0],
#         [ 1669,  5193,  1638,  ...,     0,     0,     0],
#         [ 1669,  1425,  1371,  ...,     0,     0,     0],
#         ...,
#         [  501,   259,   284,  ...,     0,     0,     0],
#         [ 1829,   261,  2262,  ...,     0,     0,     0],
#         [13889,  5810,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  313, 12571, 27613,  ...,     0,     0,     0],
#         [  259, 10837,  4875,  ...,     0,     0,     0],
#         [  313,   566, 22491,  ...,     0,     0,     0],
#         ...,
#         [  313,   566,  3609,  ...,     0,     0,     0],
#         [ 1385,   639,  1388,  ...,     0,     0,     0],
#         [ 2953,  3354,   287,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  5258,    639,    259,  ...,      0,      0,      0],
#         [   259,    277,  96668,  ...,      0,      0,      0],
#         [   313,  12571,  22163,  ...,      0,      0,      0],
#         ...,
#         [   563,    259,    262,  ...,      0,      0,      0],
#         [  3897, 101924,    265,  ...,      0,      0,      0],
#         [ 52717,    342,   3220,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  336, 11869,   345,  ...,     0,     0,     0],
#         [12949, 44394, 63682,  ...,     0,     0,     0],
#         [  486, 14802, 16603,  ...,     0,     0,     0],
#         ...,
#         [  259, 52356, 93711,  ...,     0,     0,     0],
#         [  313,   357,   263,  ...,     0,     0,     0],
#         [ 9300,   261,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  259, 10837,  2109,  ...,     0,     0,     0],
#         [ 2953,  9713,   261,  ...,     0,     0,     0],
#         [ 1494,   269, 92475,  ...,     0,     0,     0],
#         ...,
#         [  313,  2349,   259,  ...,     0,     0,     0],
#         [  259,   277, 12671,  ...,     0,     0,     0],
#         [  336,   390,  2739,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   259, 102155,    339,  ...,      0,      0,      0],
#         [   313,  35286,    898,  ...,      0,      0,      0],
#         [   336,   1425,    259,  ...,      0,      0,      0],
#         ...,
#         [   501,  59954,  15233,  ...,      0,      0,      0],
#         [  8690,    527,    287,  ...,      0,      0,      0],
#         [   563,    287,  40719,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  336, 64558,   285,  ...,     0,     0,     0],
#         [  486, 54714,   261,  ...,     0,     0,     0],
#         [ 1662,  1432,   259,  ...,     0,     0,     0],
#         ...,
#         [  313, 18491,  8818,  ...,     0,     0,     0],
#         [ 5258,   787,  1425,  ...,     0,     0,     0],
#         [  313, 28269,   418,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   486,    259, 168192,  ...,      0,      0,      0],
#         [  1385,    639,    344,  ...,      0,      0,      0],
#         [  1494,  26562,    259,  ...,      0,      0,      0],
#         ...,
#         [  4837,    259,   1909,  ...,      0,      0,      0],
#         [   313,    511,    286,  ...,      0,      0,      0],
#         [   336,  63124,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 95841,   339,  ...,     0,     0,     0],
#         [ 1477,  2621,   259,  ...,     0,     0,     0],
#         [  298,   317, 52734,  ...,     0,     0,     0],
#         ...,
#         [  313, 18283,   332,  ...,     0,     0,     0],
#         [58413,   541,   484,  ...,     0,     0,     0],
#         [ 1669,   303, 10627,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 4040,   514, 57640,  ...,     0,     0,     0],
#         [  259, 57976,   263,  ...,     0,     0,     0],
#         [  415, 57634,   639,  ...,     0,     0,     0],
#         ...,
#         [  259, 14833,   261,  ...,     0,     0,     0],
#         [ 4630,   259,  3659,  ...,     0,     0,     0],
#         [ 6898,   263,   260,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  336,   277,  1578,  ...,     0,     0,     0],
#         [  313,   357,   263,  ...,     0,     0,     0],
#         [  313,  2349,  9496,  ...,     0,     0,     0],
#         ...,
#         [ 1669, 32070,  2486,  ...,     0,     0,     0],
#         [  764,  9562,   269,  ...,     0,     0,     0],
#         [ 5100, 15740,   790,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   653,  32590,    259,  ...,      0,      0,      0],
#         [  1641,    287,    259,  ...,      0,      0,      0],
#         [  4630,  59154,    345,  ...,      0,      0,      0],
#         ...,
#         [  1669,  76478,    753,  ...,      0,      0,      0],
#         [  1829,    955,    259,  ...,      0,      0,      0],
#         [   313, 126629,  22161,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  336,   728,   259,  ...,     0,     0,     0],
#         [  259,   277, 14721,  ...,     0,     0,     0],
#         [ 1494,   639,   287,  ...,     0,     0,     0],
#         ...,
#         [ 6928,   336,   390,  ...,     0,     0,     0],
#         [ 1494,   339,   287,  ...,     0,     0,     0],
#         [ 1385,  1425,  2101,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  1385,  49979,    285,  ...,      0,      0,      0],
#         [  4837,    339,    533,  ...,      0,      0,      0],
#         [ 42376,    347,    304,  ...,      0,      0,      0],
#         ...,
#         [   313,    794,    429,  ...,      0,      0,      0],
#         [   259,    277,    638,  ...,      0,      0,      0],
#         [  1306,   2109, 107313,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  4879,    265,    304,  ...,      0,      0,      0],
#         [  1385,    339,    776,  ...,      0,      0,      0],
#         [ 34583,   8277,    639,  ...,      0,      0,      0],
#         ...,
#         [  4837,    259, 116367,  ...,      0,      0,      0],
#         [   486,    272,    261,  ...,      0,      0,      0],
#         [  1477,    288,    287,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  259, 33644, 72481,  ...,     0,     0,     0],
#         [  371,   277,   861,  ...,     0,     0,     0],
#         [  653, 20815,   295,  ...,     0,     0,     0],
#         ...,
#         [  298,  2952,  5866,  ...,     0,     0,     0],
#         [  259,   277, 35286,  ...,     0,     0,     0],
#         [ 9300,  2984,  3133,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   563,    287,  15388,  ...,      0,      0,      0],
#         [   313,   2009,  16853,  ...,      0,      0,      0],
#         [ 25713,   2561,    533,  ...,      0,      0,      0],
#         ...,
#         [   313,    638,  65065,  ...,      0,      0,      0],
#         [169450,    261,    259,  ...,      0,      0,      0],
#         [ 13889,    259,  95018,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 1641,   287,  1904,  ..., 96904,   261,     1],
#         [82161,  1582, 51366,  ...,     0,     0,     0],
#         [11651,  3029,   440,  ...,     0,     0,     0],
#         ...,
#         [  486,   272,   261,  ...,     0,     0,     0],
#         [  415, 57634, 66664,  ...,     0,     0,     0],
#         [  313,  4748,   264,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  1669,    639, 116336,  ...,      0,      0,      0],
#         [  8690,   3256,    416,  ...,      0,      0,      0],
#         [  1071,    533,    261,  ...,      0,      0,      0],
#         ...,
#         [   486,  77366,    259,  ...,      0,      0,      0],
#         [  5258,   6898,    260,  ...,      0,      0,      0],
#         [  1124,    384,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[53389, 12787,   259,  ...,     0,     0,     0],
#         [  313, 45214,  6117,  ...,     0,     0,     0],
#         [  313, 79467,   533,  ...,     0,     0,     0],
#         ...,
#         [ 1525,  2736,   702,  ...,     0,     0,     0],
#         [ 5881, 30786,   261,  ...,     0,     0,     0],
#         [ 1662,   418,   287,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   459,   7030,    259,  ...,      0,      0,      0],
#         [  1385,    303, 165998,  ...,      0,      0,      0],
#         [ 11502,    484,    261,  ...,      0,      0,      0],
#         ...,
#         [   486,    272,   2621,  ...,      0,      0,      0],
#         [  1641,   6338,   6466,  ...,      0,      0,      0],
#         [  5126,    639,    287,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  2845,   4328,    386,  ...,   2975,    269,      1],
#         [   259,  10837, 107313,  ...,      0,      0,      0],
#         [   486,  77366,    261,  ...,      0,      0,      0],
#         ...,
#         [   563,   1537,   4072,  ...,      0,      0,      0],
#         [   313,   2594,    287,  ...,      0,      0,      0],
#         [ 59463,  55735,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,  64286,    259,  ...,      0,      0,      0],
#         [   313, 118134,    344,  ...,      0,      0,      0],
#         [   336,    259,  25896,  ...,      0,      0,      0],
#         ...,
#         [ 34583,   2672,    639,  ...,      0,      0,      0],
#         [   447,   6257,    261,  ...,      0,      0,      0],
#         [   313,    545, 149728,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 12571,  6535,  ...,     0,     0,     0],
#         [  259,   277, 45214,  ...,     0,     0,     0],
#         [  259,   264,   259,  ...,     0,     0,     0],
#         ...,
#         [  313, 95841,   609,  ...,     0,     0,     0],
#         [  486,   259,  9877,  ...,     0,     0,     0],
#         [ 2368, 55324,   261,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  259, 11517, 39628,  ...,     0,     0,     0],
#         [ 7961,  9713,   261,  ...,     0,     0,     0],
#         [  259,   277, 65237,  ...,     0,     0,     0],
#         ...,
#         [ 1102,   287,   259,  ...,     0,     0,     0],
#         [  313, 18948,   914,  ...,     0,     0,     0],
#         [42958,   351,   309,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  259, 65717,   336,  ...,     0,     0,     0],
#         [  486, 20612,   304,  ...,     0,     0,     0],
#         [  336,  1425,  6504,  ...,     0,     0,     0],
#         ...,
#         [31716,   265,   261,  ...,     0,     0,     0],
#         [ 4837,   287,   276,  ...,     0,     0,     0],
#         [ 1669,  3031,   272,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[15303,   263,   259,  ...,     0,     0,     0],
#         [ 2953,   304,  2486,  ...,     0,     0,     0],
#         [ 2485,   272,   277,  ...,     0,     0,     0],
#         ...,
#         [  259,  6397,   259,  ...,     0,     0,     0],
#         [ 1669, 29202,   345,  ...,     0,     0,     0],
#         [ 1916,   609,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  313, 11780,   277,  ...,     0,     0,     0],
#         [ 1669,   259,   263,  ...,     0,     0,     0],
#         [  259,   277, 18948,  ...,     0,     0,     0],
#         ...,
#         [ 1829,   259,  4944,  ...,     0,     0,     0],
#         [  259,   277, 60286,  ...,     0,     0,     0],
#         [  486,  6801,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  653,  1371,   259,  ...,     0,     0,     0],
#         [  486,   272,   261,  ...,   259,  2220,     1],
#         [  336,   639,   259,  ...,     0,     0,     0],
#         ...,
#         [  563, 15129,   304,  ...,     0,     0,     0],
#         [  298, 20435,   287,  ...,     0,     0,     0],
#         [ 1669,   639,   317,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  4630,   4649,    345,  ...,      0,      0,      0],
#         [   764, 119697,  78585,  ...,      0,      0,      0],
#         [   336,    259,  58620,  ...,      0,      0,      0],
#         ...,
#         [   486,  25506,    639,  ...,      0,      0,      0],
#         [  1829,   8350,    336,  ...,      0,      0,      0],
#         [  3126,    259,    262,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 11780,   339,  ...,     0,     0,     0],
#         [  313, 18402,  2469,  ...,     0,     0,     0],
#         [ 1829,   527,   787,  ...,     0,     0,     0],
#         ...,
#         [ 1669,   259, 14196,  ...,     0,     0,     0],
#         [  336,   259, 25530,  ...,     0,     0,     0],
#         [ 2841,  6898,   260,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1494,   259, 42816,  ...,     0,     0,     0],
#         [  486,   272,   533,  ...,     0,     0,     0],
#         [ 5126,   261,   259,  ...,     0,     0,     0],
#         ...,
#         [  486,   259, 73266,  ...,     0,     0,     0],
#         [  486, 82387, 15740,  ...,     0,     0,     0],
#         [  313, 64210,   287,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1829,   533, 10494,  ...,     0,     0,     0],
#         [  259, 10837,   259,  ...,     0,     0,     0],
#         [ 1525,  2621,   719,  ...,     0,     0,     0],
#         ...,
#         [ 5126,   259, 22405,  ...,     0,     0,     0],
#         [49610,   259,  6768,  ...,     0,     0,     0],
#         [  259, 11517,   877,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1669, 59150,  3678,  ...,     0,     0,     0],
#         [  926, 34937,  6225,  ...,     0,     0,     0],
#         [ 5258,   261,   351,  ...,     0,     0,     0],
#         ...,
#         [ 4630,  5897,   461,  ...,     0,     0,     0],
#         [ 1797,   287,  3005,  ...,     0,     0,     0],
#         [  336,   639,   344,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  764,   259,   284,  ...,     0,     0,     0],
#         [33494,   265,   358,  ...,     0,     0,     0],
#         [  313,   566,  2477,  ...,     0,     0,     0],
#         ...,
#         [  313, 38054,   261,  ...,     0,     0,     0],
#         [  563,   461,   259,  ...,     0,     0,     0],
#         [  486,   272,   790,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  6175,   7935,   3354,  ...,      0,      0,      0],
#         [   313,  64210,    259,  ...,      0,      0,      0],
#         [   336, 136046,    345,  ...,      0,      0,      0],
#         ...,
#         [   313,  90492,    296,  ...,      0,      0,      0],
#         [   259,  29655,   3031,  ...,      0,      0,      0],
#         [  4837,   1001,  30786,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[79343,  3175,   261,  ...,     0,     0,     0],
#         [  313, 19374,  2621,  ...,     0,     0,     0],
#         [  313, 35619,   261,  ...,     0,     0,     0],
#         ...,
#         [  313, 21490,   521,  ...,     0,     0,     0],
#         [  313, 18948,   261,  ...,     0,     0,     0],
#         [  336,   259, 14196,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1662,   418, 24334,  ...,     0,     0,     0],
#         [  259,   277,   478,  ...,     0,     0,     0],
#         [ 5258,   569, 22161,  ...,     0,     0,     0],
#         ...,
#         [  313,   459,  2336,  ...,     0,     0,     0],
#         [  259, 11517, 68344,  ...,     0,     0,     0],
#         [ 6928,   261,   336,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  486, 12688,   339,  ...,     0,     0,     0],
#         [  447,  6257,   261,  ...,   259,   263,     1],
#         [ 5258,   339,  1607,  ...,     0,     0,     0],
#         ...,
#         [ 1916,  9019,   263,  ...,     0,     0,     0],
#         [  486,  8929,   304,  ...,     0,     0,     0],
#         [  259, 14833,   609,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 3946,   819,   277,  ...,     0,     0,     0],
#         [  259, 18948,  2109,  ...,     0,     0,     0],
#         [ 1669,   639,  3867,  ...,     0,     0,     0],
#         ...,
#         [11039,   265, 11047,  ...,     0,     0,     0],
#         [  313,  7968,  3086,  ...,     0,     0,     0],
#         [  486,   259,  6197,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  1819,    260,   4040,  ...,      0,      0,      0],
#         [   259,    277,  35286,  ...,      0,      0,      0],
#         [   313, 148277,    309,  ...,      0,      0,      0],
#         ...,
#         [   459,    283,    335,  ...,      0,      0,      0],
#         [   486,    259, 168192,  ...,      0,      0,      0],
#         [ 34583,    259,   9371,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 8834,  3042,   339,  ...,     0,     0,     0],
#         [ 4837,  2119,  2109,  ...,     0,     0,     0],
#         [ 4630,   259,  2220,  ...,     0,     0,     0],
#         ...,
#         [  563,   287,  6844,  ...,     0,     0,     0],
#         [23929, 27696,   345,  ...,     0,     0,     0],
#         [ 1829,  4089,  2847,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   336,    728,    776,  ...,      0,      0,      0],
#         [   259,  27531,  26031,  ...,      0,      0,      0],
#         [   336,    259,  26702,  ...,      0,      0,      0],
#         ...,
#         [ 11076,    259,   8473,  ...,      0,      0,      0],
#         [   259,    277,   9248,  ...,      0,      0,      0],
#         [  1669, 109667,    345,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313,  4748,  5546,  ...,     0,     0,     0],
#         [  486, 14802, 46292,  ...,     0,     0,     0],
#         [ 1170,   448, 18059,  ...,     0,     0,     0],
#         ...,
#         [  259,  6397,   790,  ...,     0,     0,     0],
#         [  313,  2349,   261,  ...,     0,     0,     0],
#         [ 1916,   344,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  486,   272,   261,  ...,     0,     0,     0],
#         [11674,   787,   259,  ...,     0,     0,     0],
#         [ 1385,   639,   259,  ...,     0,     0,     0],
#         ...,
#         [15737,   264,   264,  ...,     0,     0,     0],
#         [  486,   674,  1425,  ...,     0,     0,     0],
#         [  259, 29655,   339,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,    357,    259,  ...,      0,      0,      0],
#         [   259,    277,  95841,  ...,      0,      0,      0],
#         [  5100,   3506,  99107,  ...,      0,      0,      0],
#         ...,
#         [   486,   2956,    692,  ...,      0,      0,      0],
#         [   336,   5150, 128866,  ...,      0,      0,      0],
#         [   313, 169218, 118706,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   336,   2354,  11236,  ...,      0,      0,      0],
#         [   313, 168746,    541,  ...,      0,      0,      0],
#         [ 48671,   1759,   3644,  ...,      0,      0,      0],
#         ...,
#         [ 49610,    336,   1425,  ...,      0,      0,      0],
#         [   486,   1459,    259,  ...,      0,      0,      0],
#         [   313,  11780,    339,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,  11780,    277,  ...,      0,      0,      0],
#         [  1385,    639,    259,  ...,      0,      0,      0],
#         [  1494,    335, 116024,  ...,      0,      0,      0],
#         ...,
#         [  4396,    263,    305,  ...,      0,      0,      0],
#         [   259,    264,   1648,  ...,      0,      0,      0],
#         [  1494,    639,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   259,    277,  38054,  ...,      0,      0,      0],
#         [   313,  64210,    259,  ...,      0,      0,      0],
#         [  1102,    259,    262,  ...,      0,      0,      0],
#         ...,
#         [   486,  48461,    270,  ...,      0,      0,      0],
#         [   259,  14833,    261,  ...,      0,      0,      0],
#         [   486,    259, 107283,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   336,    259,  53571,  ...,      0,      0,      0],
#         [   563,   5700,    261,  ...,      0,      0,      0],
#         [  1170,    416, 128866,  ...,      0,      0,      0],
#         ...,
#         [  1794,    287,   3230,  ...,      0,      0,      0],
#         [   313,  12571,   6801,  ...,      0,      0,      0],
#         [  2894,    687,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   259,    264,   1124,  ...,      0,      0,      0],
#         [   486,  70542,   1866,  ...,      0,      0,      0],
#         [ 82161,   1582,  31533,  ...,      0,      0,      0],
#         ...,
#         [  7119,    714,    269,  ...,      0,      0,      0],
#         [  1669,    259,  15362,  ...,      0,      0,      0],
#         [   313, 132984,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   336,    259,  14037,  ...,      0,      0,      0],
#         [   501,   9573,  34827,  ...,      0,      0,      0],
#         [  4837,    259,   1909,  ...,      0,      0,      0],
#         ...,
#         [ 10887, 169088,    514,  ...,      0,      0,      0],
#         [   313,  11780,    339,  ...,      0,      0,      0],
#         [   313,  43671,    277,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 1494,   609,   639,  ...,     0,     0,     0],
#         [  313,  2009,   272,  ...,     0,     0,     0],
#         [  486,   317, 50994,  ...,     0,     0,     0],
#         ...,
#         [ 1306,   418,   776,  ...,     0,     0,     0],
#         [  486,   259, 34432,  ...,     0,     0,     0],
#         [  486,   259, 50554,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  486, 35599,  2733,  ...,     0,     0,     0],
#         [  298, 11400,   304,  ...,     0,     0,     0],
#         [ 1385,   639,   287,  ...,     0,     0,     0],
#         ...,
#         [  313, 90492,   261,  ...,     0,     0,     0],
#         [  486, 62125,   259,  ...,     0,     0,     0],
#         [  336,   639,   259,  ...,   259,  1909,     1]], device='cuda:0')
# tensor([[  313,   566, 23896,  ...,     0,     0,     0],
#         [  259,   264,  1243,  ...,     0,     0,     0],
#         [ 1662,   898,  8103,  ...,     0,     0,     0],
#         ...,
#         [ 7051,   299,   259,  ...,     0,     0,     0],
#         [ 1829,   521,  2354,  ...,     0,     0,     0],
#         [ 1071,  4368,   261,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   486, 108968,    473,  ...,      0,      0,      0],
#         [   486,    317, 192549,  ...,      0,      0,      0],
#         [  1306,   2477,    277,  ...,      0,      0,      0],
#         ...,
#         [  1477,    288,  57813,  ...,      0,      0,      0],
#         [  4837,   2250,    304,  ...,      0,      0,      0],
#         [   259,  12115,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,  12671,    521,  ...,      0,      0,      0],
#         [ 18510,    267,  11265,  ...,      0,      0,      0],
#         [  1794,  10934,    261,  ...,      0,      0,      0],
#         ...,
#         [   313,  11780,    639,  ...,      0,      0,      0],
#         [  2368,   3302, 124568,  ...,      0,      0,      0],
#         [   486,   3738,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 4630,  2426,   259,  ...,     0,     0,     0],
#         [  486,   259, 50554,  ...,     0,     0,     0],
#         [ 5258,  2109,   259,  ...,     0,     0,     0],
#         ...,
#         [ 1760, 56731,   383,  ...,     0,     0,     0],
#         [  313,   566,  1469,  ...,     0,     0,     0],
#         [  313, 91680,   914,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  313, 18402,  1432,  ...,     0,     0,     0],
#         [  313, 90600,   261,  ...,     0,     0,     0],
#         [  486,   272,   261,  ...,     0,     0,     0],
#         ...,
#         [  313, 12671,   521,  ...,     0,     0,     0],
#         [  313, 35286,   336,  ...,     0,     0,     0],
#         [  313,  2009,   272,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313, 131434,    521,  ...,      0,      0,      0],
#         [   313,  16396,    336,  ...,      0,      0,      0],
#         [  8690,   9002,    287,  ...,      0,      0,      0],
#         ...,
#         [   486,    303,    262,  ...,      0,      0,      0],
#         [ 36874,    261,   2621,  ...,      0,      0,      0],
#         [  4630,    639,   6715,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  1669,  31533,    281,  ...,      0,      0,      0],
#         [  4837,    342,    776,  ...,      0,      0,      0],
#         [   259,    277, 151478,  ...,      0,      0,      0],
#         ...,
#         [  1385,    639,    776,  ...,      0,      0,      0],
#         [   259,    277,    357,  ...,      0,      0,      0],
#         [  1494,   7834,    639,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   259,  10837,   2109,  ...,      0,      0,      0],
#         [   563,  12558,    261,  ...,      0,      0,      0],
#         [ 39579,    317, 216387,  ...,      0,      0,      0],
#         ...,
#         [  1641,    259,   3151,  ...,      0,      0,      0],
#         [   313,   2349,    261,  ...,      0,      0,      0],
#         [  1385,    639,    776,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   486,    259,  73443,  ...,      0,      0,      0],
#         [  7468,  19968,   2440,  ...,      0,      0,      0],
#         [   486, 130823,    304,  ...,      0,      0,      0],
#         ...,
#         [  3946,    737,    348,  ...,      0,      0,      0],
#         [   313,   2594,  18103,  ...,      0,      0,      0],
#         [ 39579,  18724,    639,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313,  2009,   259,  ...,     0,     0,     0],
#         [13889,   259, 27009,  ...,     0,     0,     0],
#         [  313,   399,   503,  ...,     0,     0,     0],
#         ...,
#         [  486,   259, 79269,  ...,     0,     0,     0],
#         [ 1385,   259,  2220,  ...,     0,     0,     0],
#         [ 1669,   639,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,    561,  28481,  ...,      0,      0,      0],
#         [   313,  64286,    259,  ...,      0,      0,      0],
#         [  1829,   2621,    639,  ...,      0,      0,      0],
#         ...,
#         [ 11076,    303,  14467,  ...,      0,      0,      0],
#         [175554,    270,   3644,  ...,      0,      0,      0],
#         [   764, 137690,    417,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313, 119326,   6225,  ...,      0,      0,      0],
#         [   313,  38054,    261,  ...,      0,      0,      0],
#         [   313,  90492,    261,  ...,      0,      0,      0],
#         ...,
#         [  5258,    418,   7156,  ...,      0,      0,      0],
#         [  1385,    639,    259,  ...,      0,      0,      0],
#         [   486,    784,    285,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,  11780,    339,  ...,      0,      0,      0],
#         [  1385,    639,    776,  ...,      0,      0,      0],
#         [   653,   1371,   4089,  ...,      0,      0,      0],
#         ...,
#         [   259,  35129,  20671,  ...,      0,      0,      0],
#         [   486,   3738,    259,  ...,      0,      0,      0],
#         [   313, 119326,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  259,   277,   566,  ...,     0,     0,     0],
#         [ 1385,   259,  2220,  ...,     0,     0,     0],
#         [  259, 49990,   639,  ...,     0,     0,     0],
#         ...,
#         [13889, 37430, 31738,  ...,     0,     0,     0],
#         [  313, 38054,   261,  ...,     0,     0,     0],
#         [  486, 10966,   281,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   259, 137922,    261,  ...,      0,      0,      0],
#         [   313,  12571,   2274,  ...,      0,      0,      0],
#         [   313,  15206,    287,  ...,      0,      0,      0],
#         ...,
#         [ 13889,   3029,    639,  ...,      0,      0,      0],
#         [  5126,   3031,  11535,  ...,      0,      0,      0],
#         [   259, 101388,    265,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   259,    277,  95841,  ...,      0,      0,      0],
#         [  6282,    347,  43540,  ...,      0,      0,      0],
#         [   313,    399,  33767,  ...,      0,      0,      0],
#         ...,
#         [   336,  10893,    345,  ...,      0,      0,      0],
#         [  1641,    287,   3482,  ...,      0,      0,      0],
#         [   366, 161581,    264,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  4837,   3392,    527,  ...,      0,      0,      0],
#         [  7599,   1036,    263,  ...,      0,      0,      0],
#         [   313, 119326,    261,  ...,      0,      0,      0],
#         ...,
#         [ 18869,  19425,    631,  ...,      0,      0,      0],
#         [   259,    277,  61379,  ...,      0,      0,      0],
#         [  1669,    259,  57640,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   486,  18695,  20495,  ...,      0,      0,      0],
#         [  1494,   3005,    327,  ...,      0,      0,      0],
#         [  1494,    339,   2119,  ...,      0,      0,      0],
#         ...,
#         [   259,    277, 141401,  ...,      0,      0,      0],
#         [  2841,    521,    277,  ...,      0,      0,      0],
#         [  9155,    347,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 64210,   261,  ...,     0,     0,     0],
#         [  313, 19374,  4875,  ...,     0,     0,     0],
#         [ 2584,  2262,   287,  ...,     0,     0,     0],
#         ...,
#         [  320,   277,   696,  ...,     0,     0,     0],
#         [  486,  2956, 16249,  ...,   287,  2956,     1],
#         [  486,   259, 88713,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   259, 127181,  73670,  ...,      0,      0,      0],
#         [   501,  17453,    259,  ...,      0,      0,      0],
#         [   926,   3392,  18205,  ...,      0,      0,      0],
#         ...,
#         [  1916,    287,  36600,  ...,      0,      0,      0],
#         [ 49610,    336,  14816,  ...,      0,      0,      0],
#         [  4837,    261,    281,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  2485,    609,   6644,  ...,      0,      0,      0],
#         [   336,   1425,   2561,  ...,      0,      0,      0],
#         [   501,   1798, 163625,  ...,      0,      0,      0],
#         ...,
#         [194731,    278,   3082,  ...,      0,      0,      0],
#         [   313,    621, 195430,  ...,      0,      0,      0],
#         [  1669,    277,    263,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313,  2594,   259,  ...,     0,     0,     0],
#         [ 2841,   259,   262,  ...,     0,     0,     0],
#         [  486, 44271,   639,  ...,     0,     0,     0],
#         ...,
#         [  313,   399,   503,  ...,     0,     0,     0],
#         [ 1385,   639,  6528,  ...,     0,     0,     0],
#         [  336,  3658,   772,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[55424,  3315,   331,  ...,     0,     0,     0],
#         [  313, 16730,   259,  ...,     0,     0,     0],
#         [  313, 95841,   277,  ...,     0,     0,     0],
#         ...,
#         [17495,  6910,   259,  ...,     0,     0,     0],
#         [  259,   277, 18948,  ...,     0,     0,     0],
#         [  336,   639, 29100,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  1385,    738,    277,  ...,      0,      0,      0],
#         [   259,  10837,   1425,  ...,      0,      0,      0],
#         [ 93049,  53015,    604,  ...,      0,      0,      0],
#         ...,
#         [   313, 119326,    261,  ...,      0,      0,      0],
#         [  1829,   1098,   9713,  ...,      0,      0,      0],
#         [  1641,    287,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   336,    259,  14196,  ...,      0,      0,      0],
#         [ 11502,    484,   2621,  ...,      0,      0,      0],
#         [   259, 129532,    702,  ...,      0,      0,      0],
#         ...,
#         [   352,    331,    277,  ...,      0,      0,      0],
#         [  1829,  49104,    454,  ...,      0,      0,      0],
#         [ 11076,    336,   1425,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  259,  6397,   287,  ...,     0,     0,     0],
#         [  764,   259, 62311,  ...,     0,     0,     0],
#         [  313, 65237,   569,  ...,     0,     0,     0],
#         ...,
#         [17876,   639,  2108,  ...,     0,     0,     0],
#         [  415, 57634,  6528,  ...,     0,     0,     0],
#         [  313, 65237,   261,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  4837,    783,    521,  ...,      0,      0,      0],
#         [   313,  18402,    783,  ...,      0,      0,      0],
#         [   313, 116048,    288,  ...,      0,      0,      0],
#         ...,
#         [   259,    277,   1916,  ...,      0,      0,      0],
#         [   336,    259,  31157,  ...,      0,      0,      0],
#         [   259,  18948,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,    566,    259,  ...,      0,      0,      0],
#         [   259,  37284,    259,  ...,      0,      0,      0],
#         [ 17876,    639, 108901,  ...,      0,      0,      0],
#         ...,
#         [   313,    277,    490,  ...,      0,      0,      0],
#         [   336,    259,    270,  ...,      0,      0,      0],
#         [  1385,    639,  92600,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 38054,   261,  ...,     0,     0,     0],
#         [ 7702,   609,   776,  ...,     0,     0,     0],
#         [ 1071, 69841,   261,  ...,     0,     0,     0],
#         ...,
#         [  486, 39850, 16990,  ...,     0,     0,     0],
#         [ 4630,   259,  2220,  ...,     0,     0,     0],
#         [ 4837,   714,   259,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[10934,  7029,   345,  ...,     0,     0,     0],
#         [ 1385,   339,  1371,  ...,     0,     0,     0],
#         [  259,   264,  8656,  ...,     0,     0,     0],
#         ...,
#         [  313,   566, 13636,  ...,     0,     0,     0],
#         [  259, 10837,   418,  ...,     0,     0,     0],
#         [ 1641,   340, 33619,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1477,   790,   259,  ...,     0,     0,     0],
#         [11039,   265, 11047,  ...,     0,     0,     0],
#         [ 4837,   259,  1909,  ...,     0,     0,     0],
#         ...,
#         [ 1385,   639, 20444,  ...,     0,     0,     0],
#         [  259, 96938,   344,  ...,     0,     0,     0],
#         [  486,  6368,   305,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 13889,    259, 166375,  ...,      0,      0,      0],
#         [   336,    728,   7779,  ...,      0,      0,      0],
#         [   336,  15907,    285,  ...,      0,      0,      0],
#         ...,
#         [ 11416,   5024,    261,  ...,      0,      0,      0],
#         [   313,  90492,    261,  ...,      0,      0,      0],
#         [  1829,    751,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  1829,    287,    327,  ...,      0,      0,      0],
#         [  6898,    260,    259,  ...,      0,      0,      0],
#         [  2455,   1783,  37035,  ...,      0,      0,      0],
#         ...,
#         [   486,  29333,   1425,  ...,      0,      0,      0],
#         [  1494,  38707,  12122,  ...,      0,      0,      0],
#         [  2179, 120763,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   259,  52386, 183181,  ...,      0,      0,      0],
#         [  4837, 139802,    484,  ...,      0,      0,      0],
#         [ 18869,    261,    790,  ...,      0,      0,      0],
#         ...,
#         [  1385,   5150,    390,  ...,      0,      0,      0],
#         [   313,  18402,   5231,  ...,      0,      0,      0],
#         [   259,  33806,    982,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 4837,   259, 44771,  ...,     0,     0,     0],
#         [  313, 13344,  8211,  ...,     0,     0,     0],
#         [26104,   339,   288,  ...,     0,     0,     0],
#         ...,
#         [  313,   403,   525,  ...,     0,     0,     0],
#         [  259,   277,   566,  ...,   262, 27951,     1],
#         [38718,   259, 16694,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  2544,    347,   3004,  ...,      0,      0,      0],
#         [   313,  20367,   2181,  ...,      0,      0,      0],
#         [  1669,    639,  47682,  ...,      0,      0,      0],
#         ...,
#         [   259,  10837,   2109,  ...,      0,      0,      0],
#         [   313, 130440,    261,  ...,      0,      0,      0],
#         [  2841,    521,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 11076,   2956,    259,  ...,      0,      0,      0],
#         [   313, 149549,  19878,  ...,      0,      0,      0],
#         [  1477,    332,    416,  ...,      0,      0,      0],
#         ...,
#         [  1829,    287,    276,  ...,      0,      0,      0],
#         [ 18869,    261,    790,  ...,      0,      0,      0],
#         [  2368,  16732,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   259,  85897,    287,  ...,      0,      0,      0],
#         [  4837,   1001,   2316,  ...,      0,      0,      0],
#         [   259,    264,    764,  ...,      0,      0,      0],
#         ...,
#         [   259,    277,  15206,  ...,      0,      0,      0],
#         [   313, 126629,    259,  ...,      0,      0,      0],
#         [  7119,    287,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   486,   5411,    304,  ...,      0,      0,      0],
#         [  4837,    261,  16533,  ...,      0,      0,      0],
#         [   259,  64528, 117850,  ...,      0,      0,      0],
#         ...,
#         [   313,  13673,    339,  ...,      0,      0,      0],
#         [   313,  22851,   1371,  ...,      0,      0,      0],
#         [   313,    357,    270,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313, 182756,   1647,  ...,      0,      0,      0],
#         [   313,   2349,    296,  ...,      0,      0,      0],
#         [   336,  12122,    527,  ...,      0,      0,      0],
#         ...,
#         [   259, 101388,    265,  ...,      0,      0,      0],
#         [  4630,    259, 219582,  ...,      0,      0,      0],
#         [   313,  19374,    336,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  259, 14833,   261,  ...,     0,     0,     0],
#         [  336,  4089,   345,  ...,     0,     0,     0],
# ...
#         [49234,   337,  4875,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  259,   264,   764,  ...,     0,     0,     0],
#         [ 8035,   259,   272,  ...,     0,     0,     0],
#         [ 6928,   261,  4089,  ...,     0,     0,     0],
#         ...,
#         [  313,   403,  2322,  ...,     0,     0,     0],
#         [  259, 33806,   259,  ...,     0,     0,     0],
#         [  259,   277, 22851,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  336,   259, 16694,  ...,     0,     0,     0],
#         [  313, 95841,   277,  ...,     0,     0,     0],
#         [  313,   566,  2469,  ...,     0,     0,     0],
#         ...,
#         [  486,  4119,  3212,  ...,     0,     0,     0],
#         [ 4630, 18996,   345,  ...,     0,     0,     0],
#         [ 3398, 10406,   309,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  5258, 106018,   8547,  ...,    305,   1866,      1],
#         [  8505,    339,   1638,  ...,      0,      0,      0],
#         [   259,  18948,   3609,  ...,      0,      0,      0],
#         ...,
#         [   313, 159050,   1098,  ...,      0,      0,      0],
#         [   336, 128866,    336,  ...,    281,    287,      1],
#         [   313,    566,    277,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 1669,   259,  3659,  ...,     0,     0,     0],
#         [  336, 15388,   287,  ...,     0,     0,     0],
#         [  313,   501,  3438,  ...,     0,     0,     0],
#         ...,
#         [  313, 84423,   351,  ...,     0,     0,     0],
#         [ 6928,   261,  2108,  ...,     0,     0,     0],
#         [ 2368,   335, 16527,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,  90492,    261,  ...,      0,      0,      0],
#         [ 36874,    261,    287,  ...,      0,      0,      0],
#         [   313, 116048,    261,  ...,      0,      0,      0],
#         ...,
#         [  2841,   2561,    787,  ...,    261,    787,      1],
#         [  2584,   9502,    261,  ...,      0,      0,      0],
#         [ 11076,    259,  18310,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  486,   734,  8003,  ...,     0,     0,     0],
#         [ 1829, 35005,   347,  ...,     0,     0,     0],
#         [  313, 11544, 34606,  ...,     0,     0,     0],
#         ...,
#         [  313, 69803,   533,  ...,     0,     0,     0],
#         [  313,   566,   728,  ...,     0,     0,     0],
#         [  336,   259, 36696,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1641,   287, 18695,  ...,     0,     0,     0],
#         [ 1151, 12636,   261,  ...,     0,     0,     0],
#         [31716,   265, 78585,  ...,     0,     0,     0],
#         ...,
#         [  259, 14833,   261,  ...,     0,     0,     0],
#         [  313, 35286,  6225,  ...,     0,     0,     0],
#         [  313,   566,  3076,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[1306,  783, 1711,  ...,    0,    0,    0],
#         [1494, 3315,  261,  ...,    0,    0,    0],
#         [ 298, 3265, 5038,  ...,    0,    0,    0],
#         ...,
#         [ 259,  277,  566,  ...,    0,    0,    0],
#         [2953, 3117,  277,  ...,    0,    0,    0],
#         [1641, 1638, 3230,  ...,    0,    0,    0]], device='cuda:0')
# tensor([[   259, 148377,  36881,  ...,      0,      0,      0],
#         [   313,  95841,    277,  ...,      0,      0,      0],
#         [   313,    424,  37124,  ...,      0,      0,      0],
#         ...,
#         [  8690,    527,    351,  ...,      0,      0,      0],
#         [  2816,    525,    287,  ...,      0,      0,      0],
#         [  7898,    263,   2829,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  336,   259, 18896,  ...,     0,     0,     0],
#         [ 1794,   714,   336,  ...,     0,     0,     0],
#         [ 1669,   639,   259,  ...,     0,     0,     0],
#         ...,
#         [  313, 90492,  2454,  ...,     0,     0,     0],
#         [  313, 59744,   514,  ...,     0,     0,     0],
#         [10975,   309,   609,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  2610,  42187,  51917,  ...,      0,      0,      0],
#         [  4837,    288,    264,  ...,      0,      0,      0],
#         [  1385,    639,   1037,  ...,      0,      0,      0],
#         ...,
#         [  4630,    259,  14196,  ...,      0,      0,      0],
#         [ 13889, 133633,  15745,  ...,      0,      0,      0],
#         [   486, 127991,    285,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[10975,   309,   259,  ...,     0,     0,     0],
#         [31258,  3834,  1425,  ...,     0,     0,     0],
#         [  486, 84122, 31012,  ...,     0,     0,     0],
#         ...,
#         [  259, 10837,   751,  ...,     0,     0,     0],
#         [ 2845,   982, 16826,  ...,     0,     0,     0],
#         [  313,  8729,  3644,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 4837,   259,  3151,  ...,     0,     0,     0],
#         [ 8634,   639,   281,  ...,     0,     0,     0],
#         [ 1385,   639,   776,  ...,     0,     0,     0],
#         ...,
#         [ 1648,   712,   886,  ...,     0,     0,     0],
#         [  259, 11517,   259,  ...,     0,     0,     0],
#         [  259, 10837,   394,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  563,  1427,   562,  ...,     0,     0,     0],
#         [55424,  4944,   287,  ...,     0,     0,     0],
#         [ 2953,   259,  6975,  ...,     0,     0,     0],
#         ...,
#         [  313, 28269,   738,  ...,     0,     0,     0],
#         [ 4837,   259,  5767,  ...,     0,     0,     0],
#         [  313, 35286, 41680,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[101071,    263,    309,  ...,      0,      0,      0],
#         [  1494,   2404,    259,  ...,      0,      0,      0],
#         [   486,    674,    281,  ...,      0,      0,      0],
#         ...,
#         [   486,    272,    287,  ...,      0,      0,      0],
#         [  1829,    790,  12004,  ...,      0,      0,      0],
#         [  1669,    259,  74546,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  336,   259,   263,  ...,     0,     0,     0],
#         [10266,   261,   393,  ...,     0,     0,     0],
#         [ 1641,  3392,   259,  ...,     0,     0,     0],
#         ...,
#         [  313, 95841,   277,  ...,     0,     0,     0],
#         [11076, 19078,   261,  ...,     0,     0,     0],
#         [ 3126,  1001,  1904,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,  95841,    639,  ...,      0,      0,      0],
#         [   313,    285,    277,  ...,      0,      0,      0],
#         [ 67865,   2426,    533,  ...,      0,      0,      0],
#         ...,
#         [   298,    259, 118479,  ...,      0,      0,      0],
#         [   313,  28269,    738,  ...,      0,      0,      0],
#         [  2368,  22163,    639,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 14721,   609,  ...,     0,     0,     0],
#         [15737,  1459,  3354,  ...,     0,     0,     0],
#         [48671,  1759,  3644,  ...,   776,   514,     1],
#         ...,
#         [ 4837,   287, 48016,  ...,     0,     0,     0],
#         [  486,   272,   261,  ...,     0,     0,     0],
#         [  259, 10837,  3076,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  313, 13673,  1371,  ...,     0,     0,     0],
#         [ 1306,   259, 78549,  ...,     0,     0,     0],
#         [ 1477,   259,   262,  ...,     0,     0,     0],
#         ...,
#         [  336, 14447,   287,  ...,     0,     0,     0],
#         [ 9300,   520,   259,  ...,   259,   272,     1],
#         [  259,   277,   566,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  259,   264,  5254,  ...,     0,     0,     0],
#         [10266,   261,   609,  ...,     0,     0,     0],
#         [ 1669,  1425, 31122,  ...,     0,     0,     0],
#         ...,
#         [  336,  6504,   304,  ...,     0,     0,     0],
#         [  486, 14802, 27951,  ...,     0,     0,     0],
#         [  259,   277, 78227,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,    357,    270,  ...,      0,      0,      0],
#         [  1669,    790, 170855,  ...,      0,      0,      0],
#         [  1669,   1425,    259,  ...,      0,      0,      0],
#         ...,
#         [   486,  61068, 120007,  ...,      0,      0,      0],
#         [   313,    566,    259,  ...,      0,      0,      0],
#         [   313,   9248,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  313, 18402,   783,  ...,     0,     0,     0],
#         [  313,   357, 59353,  ...,     0,     0,     0],
#         [  313,   566, 11763,  ...,     0,     0,     0],
#         ...,
#         [  313,   806, 20112,  ...,     0,     0,     0],
#         [  313,  2349, 38355,  ...,     0,     0,     0],
#         [19194,  9199,  3785,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 14197,    261,    259,  ...,      0,      0,      0],
#         [   259,  38589,  38718,  ...,      0,      0,      0],
#         [   486,    382, 194023,  ...,      0,      0,      0],
#         ...,
#         [  6550,   7655,  25483,  ...,      0,      0,      0],
#         [   313,  35619,    261,  ...,      0,      0,      0],
#         [  1306,   5150,    390,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 2841,   790, 44776,  ...,     0,     0,     0],
#         [15303, 59154,  6979,  ...,     0,     0,     0],
#         [ 1669, 19820,   259,  ...,     0,     0,     0],
#         ...,
#         [74226,   259, 52386,  ...,     0,     0,     0],
#         [  313,  6187, 36033,  ...,     0,     0,     0],
#         [  313, 35619,   309,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   313,  21490,    259,  ...,      0,      0,      0],
#         [   259, 148377,  34246,  ...,      0,      0,      0],
#         [   313,  90492,    296,  ...,      0,      0,      0],
#         ...,
#         [  1525,    287,  29711,  ...,      0,      0,      0],
#         [  7119,    287,  26331,  ...,      0,      0,      0],
#         [   926,    714,  62640,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[11502,   484,   261,  ...,     0,     0,     0],
#         [ 4630, 26766,   332,  ...,     0,     0,     0],
#         [  313, 13673,   339,  ...,     0,     0,     0],
#         ...,
#         [  336,   277,  1578,  ...,     0,     0,     0],
#         [  431,   277, 17512,  ...,     0,     0,     0],
#         [  415, 57634,  1425,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 38991,   4962,  88835,  ...,      0,      0,      0],
#         [  2106,    259,    280,  ...,      0,      0,      0],
#         [  5987, 196368,   2829,  ...,      0,      0,      0],
#         ...,
#         [   298,  45878,    304,  ...,      0,      0,      0],
#         [   313,  14721,    261,  ...,      0,      0,      0],
#         [  1118,  34606,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313, 173218,    265,  ...,      0,      0,      0],
#         [  7961,   3117,    609,  ...,      0,      0,      0],
#         [  1306,   2109,    288,  ...,      0,      0,      0],
#         ...,
#         [  1669,    390,   2739,  ...,      0,      0,      0],
#         [   486,    317,   6033,  ...,      0,      0,      0],
#         [   486,  10990,    264,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[ 1494,   335, 25505,  ...,     0,     0,     0],
#         [  313,   357,  2985,  ...,     0,     0,     0],
#         [  313, 11780,   339,  ...,     0,     0,     0],
#         ...,
#         [ 2841,   521,  2109,  ...,     0,     0,     0],
#         [  486, 36105,   514,  ...,     0,     0,     0],
#         [ 4837,  8545,   609,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 4630, 26766,  1001,  ...,     0,     0,     0],
#         [  486,   272,  1037,  ...,     0,     0,     0],
#         [ 1669,   259,  2220,  ...,     0,     0,     0],
#         ...,
#         [33833,   272,   277,  ...,     0,     0,     0],
#         [  313, 11780,   339,  ...,     0,     0,     0],
#         [  563,   287,  9995,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[ 1669,   259, 16694,  ...,     0,     0,     0],
#         [10421,  1037, 30786,  ...,     0,     0,     0],
#         [ 7483,   259,   262,  ...,     0,     0,     0],
#         ...,
#         [ 1385,  3031,   776,  ...,     0,     0,     0],
#         [ 1829,   527, 20815,  ...,     0,     0,     0],
#         [  259,  6397,  8009,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[59877,   259,  3659,  ...,     0,     0,     0],
#         [  313,   566,   783,  ...,     0,     0,     0],
#         [ 4837,  2847,   787,  ...,     0,     0,     0],
#         ...,
#         [ 1170,   259,  1465,  ...,     0,     0,     0],
#         [ 1829,   510,   259,  ...,     0,     0,     0],
#         [  259, 10837,  1425,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[  486,   272, 15740,  ...,     0,     0,     0],
#         [ 4837,  1638,   259,  ...,     0,     0,     0],
#         [ 1829,  4875,   261,  ...,     0,     0,     0],
#         ...,
#         [  313,  2009,  1916,  ...,     0,     0,     0],
#         [  313, 35286,   342,  ...,     0,     0,     0],
#         [  415, 57634,   261,  ...,     0,     0,     0]], device='cuda:0')
# tensor([[   363, 132551,    541,  ...,      0,      0,      0],
#         [  1525,   5123,    790,  ...,      0,      0,      0],
#         [   486,    259,  88713,  ...,      0,      0,      0],
#         ...,
#         [ 15841,    514,   5571,  ...,      0,      0,      0],
#         [   313,  35619,    261,  ...,      0,      0,      0],
#         [   313,  90492,    261,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  1243,  17372,    259,  ...,      0,      0,      0],
#         [   259,  64996,    772,  ...,      0,      0,      0],
#         [  1641,   8257,    261,  ...,      0,      0,      0],
#         ...,
#         [   259,    277, 173728,  ...,      0,      0,      0],
#         [  1525,    609,  13636,  ...,      0,      0,      0],
#         [   313,  37477,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313,  38054,    265,  ...,      0,      0,      0],
#         [  1829,   2561,    261,  ...,      0,      0,      0],
#         [   313,  30520, 112228,  ...,      0,      0,      0],
#         ...,
#         [  2584,    533,   3265,  ...,      0,      0,      0],
#         [   664,    277,  80812,  ...,      0,      0,      0],
#         [   313,    566,    728,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   313, 132984,    728,  ...,      0,      0,      0],
#         [   313,    621,  80131,  ...,      0,      0,      0],
#         [   259,  10837,    259,  ...,      0,      0,      0],
#         ...,
#         [  1669,  31533,   5123,  ...,      0,      0,      0],
#         [   486,  62125,    305,  ...,      0,      0,      0],
#         [   336,   1425,  46266,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[   486,    259, 107485,  ...,      0,      0,      0],
#         [  7961,    259, 104886,  ...,      0,      0,      0],
#         [   259,  10837,   2109,  ...,      0,      0,      0],
#         ...,
#         [  2584,    714,   3265,  ...,      0,      0,      0],
#         [ 19906,  64223,  35042,  ...,      0,      0,      0],
#         [  1477,    336,  12747,  ..., 119926,    510,      1]],
#        device='cuda:0')
# tensor([[   313,    566,    259,  ...,      0,      0,      0],
#         [   486,   1371,  12688,  ...,      0,      0,      0],
#         [   371,  65208,   3644,  ...,      0,      0,      0],
#         ...,
#         [  1829,   2108,    787,  ...,      0,      0,      0],
#         [   259,    277,    566,  ...,      0,      0,      0],
#         [   259, 105907,    259,  ...,      0,      0,      0]],
#        device='cuda:0')
# tensor([[  6928,    787,    259,  ...,      0,      0,      0],
#         [   313,  65237,   7176,  ...,      0,      0,      0],
#         [   313,  90492,    261,  ...,      0,      0,      0],
#         ...,
#         [   486,  29711, 169932,  ...,      0,      0,      0],
#         [ 42589,    347,    259,  ...,      0,      0,      0],
#         [  4837,    287,   6583,  ...,  93711,  41460,      1]],
#        device='cuda:0')

# %%
print("Number of generated translations:", len(generated_translations))
print("Number of references:", len(references))
# Out:
# Number of generated translations: 25417
# Number of references: 25417

# %%
print(generated_translations)
# Out:
# ["Altamira la regarda d'un etonnement ; Julien n'osait pas la regarder.", "-- Deja vide, cor-boeuf! et je n'ai plus d'argent!", "Le sourd l'avait referme derriere lui quand il entrait dans la galerie; Jehan s'etait cache derriere un roi de pierre, ne voulant pas respirer, et fixant sur", 'Vous ne ferez pas plus que de dire adieu, Jane?', "Vous ne trompez pas une femme comme moi, mon cher ami, malheureusement, je suis encore trop jeune et trop bonne pour accepter la partie que vous m'offrez.", "-- Bon! s'ecria-t-elle, j'aime que vous me pensez ainsi.", "Quelquefois je sortis dans elle pour me distraire, mais aucun voyage plus dangereux ne m'en allait jamais, a peine au-dessus d'une pierre ou deux de la ", "Enfin il se sentait affaibli par l'idee du devoir.", "On eut cru que je n'aurais pas eu le moindre reflet sur mon esprit de ma situation, pendant que je fis cette barque, mais j'aurais cru immediatement songer a", '-- Les imbeciles! repeta M. Hennebeau; suis-je heureux?', "J'obeis ses directions.", '--Saint-Valery; mais ecoutez, quand vous avez arrive la, vous allez faire une taverne sans nom et sans signe, une seule cabane du pecheur; vous ne pou', "Vous vous rappelez qu'il y avait un vieux officier de la presqu'ile qui ne vivait pas de nous, le meme qui dansait autour du feu avec sa soeur et les ", '-- Nous attendrons.', "C'etait l'ecorce de la grange voisine, a laquelle trois marches de pierre donnaient trois marches.", "Il parlait de la congestion des poitrines, de l'embolisme.", 'Mes parents essayerent de le remercier, mais il les coupa court.', "Le soleil seul gardait sa grande tranquillite; il descendait vers l'horizon, eclatant sur les arbres ecrasees et sur les volets blancs, immenses draps", "Le sol de l'Universite etait montagneux; le mont Sainte-Geneveieve formait une enorme tombee au sud; et c'etait une vue de voir du sommet de Notre", "Je vous ai dit que j'envoyerais Adele a l'ecole, et que voulez-vous avec un enfant pour un compagnon, et non pas mon enfant, avec la bonne", "Et j'ai ferme le bois ou les gens de Fernworthy s'etaient promenes.", 'Ils faisaient souper, des cheminees fumaient, une femme apparaissait a intervalles eloignes, ouvrit une porte et disparut.', "Pierre ne s'apprit pas ni de ces noms.", "- Ainsi notre capitaine ne va pas s'enfoncer ses ancres, mettre ses machineaux sur les chaines, et faire quelque chose a nous rattraper?", "-- Maintenant, vous me hainez bien, dis-je; il est inutile de vous tenter de vous conciliar; je vois que j'ai fait un ennemi eternel de vous.", 'In this moment, a sort of gaiety appeared in the character of the Duchessa.', "C'etait une raison sonore, mais Julien, passant par tous les auberges, n'avait pas le courage d'entrer dans l'un d'eux.", 'Elle pleuvait, elle jura.', "Elle vit et entendit, sans doute, elle raisonnait d'une maniere distincte et claire; mais elle n'etait pas sans geste et sans voix pour exprimer la pensee qui s'", 'Alors il disparut sur la colline.', "Cette fois s'ecoula.", "Mais laissez-moi vous dire tout, juste a l'ordre qu'il s'est passe.", 'The Duchessa never returned to her anxiety, she could not recognised him to see him pass in the street; she found him that he was in fact, one of the most pretty men in Italy; he had', "-- Camille me laisse en paix, dit Laurent pale et tremblant, c'est vous qui le voyez devant vous dans vos nuits; j'ai entendu vous crier.", "- Il est fou! un chirurgien! un chirurgien! s'ecrierent-ils.", 'Ou est-il?', "En pensant ainsi, il glissa, avec la souplesse d'un serpent, aux branches les plus basses, dont les extremites s'ecartaient presque jusqu'au sol.", "- Vous, qui connaissez si bien mon sentiment envers Mr. Darcy, comprenez bien qu'il faut bien rejoindre qu'il est assez sage pour s'assurer meme ", '--Et voici la marque, mon enfant, dit-elle; et, tirant sa gants, regardez-vous ici, dit-elle en tournant la paume de sa main, et me montra un bras', 'Mais moi, et les autres qui continuaient bien, jouissaient pleinement  ...

# %%
#print(references[10])

# %%
# Calculate Character Error Rate (CER) and Word Error Rate (WER)
results_CER = cer_metric.compute(predictions=generated_translations, references=references)
results_WER = wer_metric.compute(predictions=generated_translations, references=references)

# Calculate Exact Match (EM) and METEOR(M)
results_em = exact_match_metric.compute(predictions=generated_translations, references=references)
results_met = meteor.compute(predictions=generated_translations, references=references)

# Calculate Bilingual Evaluation Understudy (BLEU) and Recall-Oriented Understudy for Gisting Evaluation (ROUGE)
results_bleu = bleu_metric.compute(predictions=generated_translations, references=references)
results_rouge = rouge_metric.compute(predictions=generated_translations, references=references)


# Calculate Levenshtein Distance
levenshtein_distances = [Levenshtein.distance(generated, reference) for generated, reference in zip(generated_translations, references)]

# %%
print(results_CER)
print(results_WER)
print(results_em)
print(results_met)
print(results_bleu)
print(results_rouge)
# Out:
# 0.525822304529566
# 0.7046261002886353
# {'exact_match': 0.02069481055986151}
# {'meteor': 0.4805252735868863}
# {'bleu': 0.2082920785574104, 'precisions': [0.5777795946733165, 0.32172533191898545, 0.19995666651461935, 0.12818583085694374], 'brevity_penalty': 0.7928059699645588, 'length_ratio': 0.8115718684060356, 'translation_length': 489235, 'reference_length': 602824}
# {'rouge1': 0.5313357441338813, 'rouge2': 0.30747080760673773, 'rougeL': 0.5001136603163561, 'rougeLsum': 0.5001265135912111}

# %%
total_correct = 0
total_samples = len(references)

for generated, reference in zip(generated_translations, references):
    levenshtein_distance = Levenshtein.distance(generated, reference)
    max_length = max(len(generated), len(reference))
    accuracy = 1 - (levenshtein_distance / max_length)
    if accuracy >= 0.5:  # Adjust the threshold as needed
        total_correct += 1

accuracy = total_correct / total_samples
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5792973206908761

# %% [markdown]
# # **Save translation results to a csv file**

# %%
import pandas as pd

# Create a DataFrame to store translations
translation_df = pd.DataFrame({
    'input_text': test_data['input_text'],  # Assuming 'test_data' contains your test dataset
    'labels': references,
    'translations': generated_translations
})

# Save translations to a CSV file
#translation_df.to_csv("/content/drive/MyDrive/sylhet_translation_results/sylhet_translation_mT5/model_fine_tuned/mBERT_sylhet_translation.csv", index=False)
# Save translations to a CSV file
translation_df.to_excel('E:\\Fariya\\translation\\fr_translations_mT5.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[40], line 13
#       4 translation_df = pd.DataFrame({
#       5     'input_text': test_data['input_text'],  # Assuming 'test_data' contains your test dataset
#       6     'labels': references,
#       7     'translations': generated_translations
#       8 })
#      10 # Save translations to a CSV file
#      11 #translation_df.to_csv("/content/drive/MyDrive/sylhet_translation_results/sylhet_translation_mT5/model_fine_tuned/mBERT_sylhet_translation.csv", index=False)
#      12 # Save translations to a CSV file
# ---> 13 translation_df.to_excel('E:\\Fariya\\translation\\fr_translations_mT5.xlsx', index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\excel.py:944, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     940     need_save = False
#     941 else:
#     942     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944     writer = ExcelWriter(  # type: ignore[abstract]
#     945         writer, engine=engine, storage_options=storage_options
#     946     )
#     947     need_save = True
#     949 try:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1313, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1309 self._handles = IOHandles(
#    1310     cast(IO[bytes], path), compression={"compression": None}
#    1311 )
#    1312 if not isinstance(path, ExcelWriter):
# -> 1313     self._handles = get_handle(
#    1314         path, mode, storage_options=storage_options, is_text=False
#    1315     )
#    1316 self._cur_sheet = None
#    1318 if date_format is None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'E:\Fariya\translation'
